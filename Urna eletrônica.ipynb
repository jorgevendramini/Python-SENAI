# %% [markdown]
# # Atividade Urna de Votação

# %%
from IPython.display import Image, display
display(Image(filename='urnas.jpeg', width=400, height=300))  # Substitua 300 e 200 pelos valores desejados
# Colocar uma imagem do arquivo local

# %% [markdown]
# ### Chegou o momento de concluirmos nosso ciclo de aprendizado em backend com Python! Desde as primeiras linhas de código até as estruturas condicionais e comparadores, exploramos um mundo de possibilidades. Agora, vamos aplicar nosso conhecimento em um projeto empolgante: a criação de uma "Urna Eletrônica" para as futuras votações na Escola SENAI Morvan Figueiredo.

# %% [markdown]
# ### Objetivo:
# ####   Criar uma urna eletrônica em Python para realizar uma simulação de votação entre candidatos fictícios na escola SENAI Morvan Figueiredo.

# %% [markdown]
# ### Descrição:
#
# #### Na "Urna Eletrônica" que vamos desenvolver, cada grupo de alunos será responsável por construir um sistema simulado de votação. Os candidatos imaginários, e todos terão a oportunidade de exercer seu direito de voto em um ambiente virtual.
#
# ### Passos da Atividade:
#
# #### Passo 1: Forme equipes no máximo 3 alunos.
#
#
#
# #### Passo 2: Criando os Candidatos e Partidos
#
# #### Criar uma lista de candidatos fictícios, atribuindo a cada um um nome, número e partido imaginário.
#
# #### Passo 3: Simulando a Votação
#
# #### Implemente um loop de votação que permita que os alunos escolham um candidato apenas pelo número.
# #### Use um dicionário para registrar a quantidade de votos que cada candidato recebeu.
#
# #### Passo 4: Contagem e Anúncio dos Resultados
#
# #### Ao encerrar a votação, exiba um relatório com os resultados da votação.
# #### Mostre os candidatos, seus números, partidos e a quantidade de votos recebidos por cada um.
# #### Anuncie o candidato vencedor, aquele que recebeu mais votos.

# %% [markdown]
# ### Lembrete:
# #### Esta atividade não é apenas sobre programar, mas também sobre compreender a importância das eleições, trabalhar em equipe e aplicar conceitos de programação em cenários do mundo real.

# %%
# Desenvolva seu código aqui!

candidatos = {}

def menu_principal():

    print("ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO")
    print("")
    
    while True:
        print("1. Registro de Candidatos")
        print("2. Votação")
        print("3. Encerrar Programa")
        
        option = input("")
        print("")
            
        if(option == "1"):
            menu_candidatos()
                
        elif(option == "2"):
            menu_votacao()

        elif(option == "3"):
            fechar_programa()
            break
            
        else:
            print("Digite uma opção válida!")

def menu_candidatos():
    print("""ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
   **** CADASTRO DE CANDIDATOS: ****
    """)
    
    print("1. Registrar Candidato")
    print("2. Relatório de Candidatos disponíveis")
    print("3. Voltar ao Menu Principal")
    print("")

    option = input("")
            
    if(option == "1"):
        registro_candidato()
                
    elif(option == "2"):
        relatorio()

    elif(option == "3"):
        menu_principal()
            
    else:
        print("Digite uma opção válida!")
    


def menu_votacao():
    print("""ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
       **** OPÇÕES DE VOTAÇÃO: ****
    """)
    print("")

    print("1. Iniciar Votação")
    print("2. Relatório Final da Votação")
    print("3. Voltar ao Menu Principal")
    print("")

    option = input("")
    print("")
            
    if(option == "1"):
        iniciar_votacao()
                
    elif(option == "2"):
        relatorio_final()

    elif(option == "3"):
        menu_principal()
            
    else:
        print("Digite uma opção válida!")


def fechar_programa():
    print("""ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
**** PROGRAMA ENCERRADO COM SUCESSO ****
    """)

def registro_candidato():

    nome = input("Nome do Candidato: ")
    numero = input("Número: ")
    partido = input("Partido:")
    votos = 0
    cadastrar_candidato(nome, numero, partido, votos)

def cadastrar_candidato(nome, numero, partido, votos):

    if numero not in [num for _, (num, _, _) in candidatos.items()]:
        candidatos[nome] = (numero, partido, votos)
        print("Candidato {} registrado com sucesso.\n".format(nome))
    else:
        print("Número para votação já escolhido")
    continuar = input("Deseja continuar registrando? (Y/N)").upper()

    if continuar == "Y":
        registro_candidato()
    elif continuar == "N":
        menu_candidatos()
    else:
        print("Digite uma opção válida!")

def relatorio():
    for candidato, (numero, partido, votos) in candidatos.items():
        print("Candidato: {} | Numero: {} | Partido: {}".format(candidato, numero, partido))
    menu_candidatos()


def iniciar_votacao():

    number = 0

    while True:
        print("""ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
        **** VOTE CONSCIENTE ****
        **** ESCOLHA SEU CANDIDATO: ****
    """)
        print("")

        #print("Números de candidatos disponíveis:")
        #for candidato, (numero, partido) in candidatos.items():
         #   print("Número: {}".format(numero))

        print("")
        number = str(input("Digite o número de seu candidato:"))

        if number == "9876543210":
            break
        candidate_found = False
        for candidato, (numero, partido, votos) in candidatos.items():
            if str(number) == numero:
                print(f"Você vai vota no candidato: {candidato}")
                continuar = input("Deseja prosseguir? (Y/N)").upper()
                if continuar == "Y":
                    candidatos[candidato] = (numero, partido, votos + 1)
                    print(f"Voto adicionado para o candidato: {candidato}")
                elif continuar == "N":
                    print("Votação para esse candidato foi encerrada.")
                else:
                    print("Digite uma opção válida!")
                candidate_found = True
        if not candidate_found:
            print("Candidato não encontrado.")

def relatorio_final():
    for candidato, (numero, partido, votos) in candidatos.items():
        print("Candidato: {} | Numero: {} | Partido: {} | Votos: {}".format(candidato, numero, partido, votos))

menu_principal()
# Out:
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#
# 1. Registro de Candidatos
# 2. Votação
# 3. Encerrar Programa
#  1
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#    **** CADASTRO DE CANDIDATOS: ****
#
# 1. Registrar Candidato
# 2. Relatório de Candidatos disponíveis
# 3. Voltar ao Menu Principal
#  2
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#    **** CADASTRO DE CANDIDATOS: ****
#
# 1. Registrar Candidato
# 2. Relatório de Candidatos disponíveis
# 3. Voltar ao Menu Principal
#  1
# Nome do Candidato:  Jorge
# Número:  12
# Partido: PT
# Candidato Jorge registrado com sucesso.
# Deseja continuar registrando? (Y/N) y
# Nome do Candidato:  Bozo
# Número:  22
# Partido: PL
# Candidato Bozo registrado com sucesso.
# Deseja continuar registrando? (Y/N) n
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#    **** CADASTRO DE CANDIDATOS: ****
#
# 1. Registrar Candidato
# 2. Relatório de Candidatos disponíveis
# 3. Voltar ao Menu Principal
#  2
# Candidato: Jorge | Numero: 12 | Partido: PT
# Candidato: Bozo | Numero: 22 | Partido: PL
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#    **** CADASTRO DE CANDIDATOS: ****
#
# 1. Registrar Candidato
# 2. Relatório de Candidatos disponíveis
# 3. Voltar ao Menu Principal
#  3
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#
# 1. Registro de Candidatos
# 2. Votação
# 3. Encerrar Programa
#  2
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#        **** OPÇÕES DE VOTAÇÃO: ****
#
#
# 1. Iniciar Votação
# 2. Relatório Final da Votação
# 3. Voltar ao Menu Principal
#  1
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 25
# Candidato não encontrado.
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 22
# Você vai vota no candidato: Bozo
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Bozo
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 12
# Você vai vota no candidato: Jorge
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Jorge
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 12
# Você vai vota no candidato: Jorge
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Jorge
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 12
# Você vai vota no candidato: Jorge
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Jorge
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 2
# Candidato não encontrado.
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 22
# Você vai vota no candidato: Bozo
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Bozo
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 12
# Você vai vota no candidato: Jorge
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Jorge
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 12
# Você vai vota no candidato: Jorge
# Deseja prosseguir? (Y/N) y
# Voto adicionado para o candidato: Jorge
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#         **** VOTE CONSCIENTE ****
#         **** ESCOLHA SEU CANDIDATO: ****
# Digite o número de seu candidato: 9876543210
# 1. Registro de Candidatos
# 2. Votação
# 3. Encerrar Programa
#  2
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
#        **** OPÇÕES DE VOTAÇÃO: ****
#
#
# 1. Iniciar Votação
# 2. Relatório Final da Votação
# 3. Voltar ao Menu Principal
#  2
# Candidato: Jorge | Numero: 12 | Partido: PT | Votos: 5
# Candidato: Bozo | Numero: 22 | Partido: PL | Votos: 2
# 1. Registro de Candidatos
# 2. Votação
# 3. Encerrar Programa
#  3
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
# **** PROGRAMA ENCERRADO COM SUCESSO ****
#
# 1. Registro de Candidatos
# 2. Votação
# 3. Encerrar Programa
#  3
# ELEIÇÕES 2023 - SENAI MORVAN FIGUEIREDO
# **** PROGRAMA ENCERRADO COM SUCESSO ****
